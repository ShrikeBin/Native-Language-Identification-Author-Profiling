# %% [markdown]
# # Native Language Identification - Author Profiling

# %% [markdown]
# ### Fill with models you want to test:
#
# Possible arguments for the Model:
# - trait_name
#     - 'language'
#     - 'age'
#     - 'gender'
#     - 'political'
#     - 'mbti'
# - head_type
#     - 'classification'
#     - 'regression'
#     - 'classreg' - an experimental regression head using 1 class classifier and it's raw logits
#     - 'convolution'
#     - 'customCNN' - an experimental CNN without transformers
# - model
#     - 'DistilBERT' - default
#     - 'MpNet'
#     - 'RoBERT'
#     - 'RoBERTLarge'
#     - 'DeBerta'
# - train
#     - 'Full' - default
#     - 'LoRA'
#     - 'Baseline'

# %%
from Testing.shap.ModelWrapper.model_wrapper import Model

models = [
    Model('age', 'Regression', model='DistilBERT', train='LoRA'),
    Model('gender', 'Classification', train='Full'),
    Model('language', 'MixedCNN', model='RoBERTa'),
    Model('language', 'MixedCNN', model='RoBERTaLarge'),
]
# Out:
# Initialized model age (DistilBERT Regression LoRA)
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     477 if len(full_filenames) == 1:
#     478     # This is slightly better for only 1 file
# --> 479     hf_hub_download(
#     480         path_or_repo_id,
#     481         filenames[0],
#     482         subfolder=None if len(subfolder) == 0 else subfolder,
#     483         repo_type=repo_type,
#     484         revision=revision,
#     485         cache_dir=cache_dir,
#     486         user_agent=user_agent,
#     487         force_download=force_download,
#     488         proxies=proxies,
#     489         resume_download=resume_download,
#     490         token=token,
#     491         local_files_only=local_files_only,
#     492     )
#     493 else:
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'Training/MODELS/gender/DistilBERTClassificationBaseline/model'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 from Testing.shap.ModelWrapper.model_wrapper import Model
#       3 models = [
#       4     Model('age', 'Regression', model='DistilBERT', train='LoRA'),
# ----> 5     Model('gender', 'Classification', train='Baseline'),
#       6     Model('language', 'MixedCNN', model='RoBERTa'),
#       7     Model('language', 'MixedCNN', model='RoBERTaLarge'),
#       8 ]
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/Testing/shap/ModelWrapper/model_wrapper.py:46, in Model.__init__(self, trait_name, head_type, model, train)
#      43 path = f"Training/MODELS/{trait_name}/{model}{head_type}{train}/model"
#      45 if head_type == 'Classification': # Transformers Classifiers
# ---> 46     self.model = AutoModelForSequenceClassification.from_pretrained(path, num_labels=len(self.label_map))
#      47 else: # Custom Head
#      48     head_module_path = f"Testing.shap.ModelWrapper.custom_heads.{head_type}"
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:508, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     505 if commit_hash is None:
#     506     if not isinstance(config, PretrainedConfig):
#     507         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# --> 508         resolved_config_file = cached_file(
#     509             pretrained_model_name_or_path,
#     510             CONFIG_NAME,
#     511             _raise_exceptions_for_gated_repo=False,
#     512             _raise_exceptions_for_missing_entries=False,
#     513             _raise_exceptions_for_connection_errors=False,
#     514             **hub_kwargs,
#     515         )
#     516         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     517     else:
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)    320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/transformers/utils/hub.py:532, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     524     raise OSError(
#     525         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     526         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     527         "2) a previous download was canceled and the lock file needs manual removal."
#     528     ) from e
#     530 # Now we try to recover if we can find all files correctly in the cache
#     531 resolved_files = [
# --> 532     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     533     for filename in full_filenames
#     534 ]
#     535 if all(file is not None for file in resolved_files):
#     536     return resolved_files
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/transformers/utils/hub.py:143, in _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision, repo_type)
#     135 def _get_cache_file_to_return(
#     136     path_or_repo_id: str,
#     137     full_filename: str,
#    (...)    141 ):
#     142     # We try to see if we have a cached version (not up to date):
# --> 143     resolved_file = try_to_load_from_cache(
#     144         path_or_repo_id, full_filename, cache_dir=cache_dir, revision=revision, repo_type=repo_type
#     145     )
#     146     if resolved_file is not None and resolved_file != _CACHED_NO_EXIST:
#     147         return resolved_file
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File ~/Documents/Native-Language-Identification-Author-Profiling/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     151     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#     160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#     162         " forbidden, '-' and '.' cannot start or end the name, max length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'Training/MODELS/gender/DistilBERTClassificationBaseline/model'. Use `repo_type` argument if needed.

# %% [markdown]
# ### Function for explanations

# %%
def explain(text):
    for model in models:
        print(model.prediction_string(text))
        print(model.explanation_string(text))
        print("=" * 80)

# %% [markdown]
# ### Test your text:

# %%
explain("Query routing, the task to route user queries to different large language model (LLM) endpoints, \
        can be considered as a text classification problem. However, out-of-distribution queries must be handled properly, \
        as those could be about unrelated domains, queries in other languages, or even contain unsafe text. \
        Here, we thus study a guarded query routing problem, for which we first introduce the Guarded Query \
        Routing Benchmark (GQR-Bench, released as Python package gqr), covers three exemplary target domains \
        (law, finance, and healthcare), and seven datasets to test robustness against out-of-distribution queries. \
        We then use GQR-Bench to contrast the effectiveness and efficiency of LLM-based routing mechanisms \
        (GPT-4o-mini, Llama-3.2-3B, and Llama-3.1-8B), standard LLM-based guardrail approaches \
        (LlamaGuard and NVIDIA NeMo Guardrails), continuous bag-of-words classifiers \
        (WideMLP, fastText), and traditional machine learning models (SVM, XGBoost). \
        Our results show that WideMLP, enhanced with out-of-domain detection capabilities, \
        yields the best trade-off between accuracy (88%) and speed (<4ms). The embedding-based fastText \
        excels at speed (<1ms) with acceptable accuracy (80%), whereas LLMs yield the highest accuracy (91%) \
        but are comparatively slow (62ms for local Llama-3.1:8B and 669ms for remote GPT-4o-mini calls). \
        Our findings challenge the automatic reliance on LLMs for (guarded) query routing and provide \
        concrete recommendations for practical applications. Source code is available: this https URL.")
# Out:
# language (RoBERT mixedCNN Full): Chinese (74.77%)
# Query routing, the task to route user queries to different large language model (LLM) endpoints,         can be considered as a text classification problem. However, out-of-distribution queries must be handled properly,         as those could be about unrelated domains, queries in other languages, or even contain unsafe text.         Here, we thus study a guarded query routing problem, for which we first introduce the Guarded Query         Routing Benchmark (GQR-Bench, released as Python package gqr), covers three exemplary target domains         (law, finance, and healthcare), and seven datasets to test robustness against out-of-distribution queries.         We then use GQR-Bench to contrast the effectiveness and efficiency of LLM-based routing mechanisms         (GPT-4o-mini, Llama-3.2-3B, and Llama-3.1-8B), standard LLM-based guardrail approaches         (LlamaGuard and NVIDIA NeMo Guardrails), continuous bag-of-words classifiers         (WideMLP, fastText), and traditional machine learning models (SVM, XGBoost).         Our results show that WideMLP, enhanced with out-of-domain detection capabilities,         yields the best trade-off between accuracy (88%) and speed (<4ms). The embedding-based fastText         excels at speed (<1ms) with acceptable accuracy (80%), whereas LLMs yield the highest accuracy (91%)         but are comparatively slow (62ms for local Llama-3.1:8B and 669ms for remote GPT-4o-mini calls).         Our findings challenge the automatic reliance on LLMs for (guarded) query routing and provide         concrete recommendations for practical applications. Source code is available: this https URL.
# ================================================================================

# %%
explain("I love pizza, even thou im not from italy, like, do italians eaven love pizza? \
    they are from that country that invented it arent they? how could they not love pizza, \
        it's as if we did not like hambugers.")
# Out:
# language (RoBERT mixedCNN Full): Spanish (84.59%)
# I love pizza, even thou im not from italy, like, do italians eaven love pizza?     they are from that country that invented it arent they? how could they not love pizza,         it's as if we did not like hambugers.
# ================================================================================
