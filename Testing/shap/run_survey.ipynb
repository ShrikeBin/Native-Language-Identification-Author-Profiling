# %% [markdown]
# # Native Language Identification - Author Profiling

# %% [markdown]
# ### Fill with models you want to test:
#
# Possible arguments for the Model:
# - trait_name
#     - 'language'
#     - 'age'
#     - 'gender'
#     - 'political'
#     - 'mbti'
# - head_type
#     - 'classification'
#     - 'regression'
#     - 'classreg' - an experimental regression head using 1 class classifier and it's raw logits
#     - 'convolution'
# - model
#     - default: DistilBERT
#     - 'MpNet'
#     - 'RoBERT'
#     - 'RoBERTLarge'
#     - 'DeBerta'
# - train
#     - default: Full
#     - 'LoRA'
#     - 'Baseline'

# %%
from Testing.shap.ModelWrapper.model_wrapper import Model

models = [
    Model('language', 'Classification', model='DistilBERT'),
    Model('language', 'Classification', model='RoBERTa'),
    Model('language', 'MixedCNN', model='RoBERTa'),
    Model('language', 'MixedCNN', model='RoBERTaLarge'),
]
# Out:
# Initialized model language (DistilBERT Classification Full)
# Initialized model language (RoBERTa Classification Full)
# Initialized model language (RoBERTa MixedCNN Full)
# Initialized model language (RoBERTaLarge MixedCNN Full)

# %% [markdown]
# ### Function for explanations

# %%
def explain(text):
    for model in models:
        print(model.prediction_string(text))
        print(model.explanation_string(text))

# %% [markdown]
# ### Survey Data, Texts and Predictions:

# %% [markdown]
# ---
# - age: 23
# - gender: Male
# - political: Right
# - mbti: ISTJ
# - native language branch: Russian

# %%
explain('I am currently working on a small project about machine learning and chess. The task is to predict Elo rating of a player based on moves that were played in a chess game. I am using data from Lichess Database, they have a lot of games recorded. Currently I am using Python with some libraries for this project. Main steps are: parsing data, creating features from moves, building a machine learning model, and showing plots for the results. All features are created manually, based on some observations about how chess works. I thought about building a neural network to get more advanced model, but I prefer more interpretation in my model, not just a black box. However, I am thinking about creating an automated feature-builder for more complex features, such as "accuracy of moving the Queen during the endgame", where multiple conditions meet.')
# Out:
# language (DistilBERT Classification Full): Spanish (82.26%)
# I am currently working on a small project about machine learning and chess. The task is to predict Elo rating of a player based on moves that were played in a chess game. I am using data from Lichess Database, they have a lot of games recorded. Currently I am using Python with some libraries for this project. Main steps are: parsing data, creating features from moves, building a machine learning model, and showing plots for the results. All features are created manually, based on some observations about how chess works. I thought about building a neural network to get more advanced model, but I prefer more interpretation in my model, not just a black box. However, I am thinking about creating an automated feature-builder for more complex features, such as "accuracy of moving the Queen during the endgame", where multiple conditions meet.
# language (RoBERTa Classification Full): Polish (53.94%)
# ...

# %% [markdown]
# ---
# - age: 50
# - gender: Female
# - political: Left
# - mbti: ENFJ
# - native language branch: Polish

# %%
explain('awkward situacion when I was laughing at the funeral. people misandertood my jokes often. I would change peoples minds, to they think better. to not give a shit to other people, dont waste they time')
# Out:
# language (DistilBERT Classification Full): Spanish (88.15%)
# awkward situacion when I was laughing at the funeral. people misandertood my jokes often. I would change peoples minds, to they think better. to not give a shit to other people, dont waste they time
# language (RoBERTa Classification Full): Spanish (74.45%)
# awkward situacion when I was laughing at the funeral. people misandertood my jokes often. I would change peoples minds, to they think better. to not give a shit to other people, dont waste they time
# language (RoBERTa MixedCNN Full): Spanish (78.97%)
# awkward situacion when I was laughing at the funeral. people misandertood my jokes often. I would change peoples minds, to they think better. to not give a shit to other people, dont waste they time
# language (RoBERTaLarge MixedCNN Full): Spanish (92.72%)
# ...

# %% [markdown]
# ---
# - age: 50
# - gender: Male
# - political: Right
# - mbti: ENTP
# - native language branch: Polish

# %%
explain("​Political Gridlock: It drives polarization by encouraging people to only consume news and evidence from sources that validate their existing political identity, making consensus and compromise nearly impossible. ​Scientific Stagnation: It leads individuals and groups to dismiss robust scientific findings on issues like climate change or public health because the data conflicts with their worldview. This prevents unified action on critical global challenges. Conflict: It fuels inter-group conflict by reinforcing negative stereotypes and making individuals unwilling to consider alternative perspectives or evidence of an opposing group's positive motives. ​By reducing the automatic, biased filtration of information, people would be more receptive to objective facts and diverse viewpoints, leading to better-informed decisions for the collective good. ​Would you like to discuss the Fundamental Attribution Error next, or ask about its impact on a specific global issue?")
# Out:
# language (DistilBERT Classification Full): French (45.59%) Arabic (9.40%)
# ...

# %% [markdown]
# ---
# - age: 23
# - gender: Male
# - political: Right
# - mbti: ENTP
# - native language branch: Koreanic

# %%
explain("If I could change one thing about the world, I would like to notice all people to focus on present. I mean not the past one. Most of people couldn't recognize the importance of enjoying the present. During my exchange period which isn't finished yet, I traveled quite a lot, I just thought we are missing smile while focusing on the future or regretting about the past things.")
# Out:
# language (DistilBERT Classification Full): Koreanic (61.42%)
# If I could change one thing about the world, I would like to notice all people to focus on present. I mean not the past one. Most of people couldn't recognize the importance of enjoying the present. During my exchange period which isn't finished yet, I traveled quite a lot, I just thought we are missing smile while focusing on the future or regretting about the past things.
# language (RoBERTa Classification Full): Koreanic (71.24%)
# If I could change one thing about the world, I would like to notice all people to focus on present. I mean not the past one. Most of people couldn't recognize the importance of enjoying the present. During my exchange period which isn't finished yet, I traveled quite a lot, I just thought we are missing smile while focusing on the future or regretting about the past things.
# language (RoBERTa MixedCNN Full): Koreanic (74.92%)
# ...

# %% [markdown]
# ---
# - age: 30
# - gender: Female
# - political: Left
# - mbti: INTJ
# - native language branch: English

# %%
explain("The other day, my middle-aged colleague got in an argument with our new hire, Sandra, because he told her she looked like his ex-wife. When Sandra told me about this conversation, she said, “I’m beginning to think Karl (colleague) isn’t a girls’ girl.” I thought that was pretty funny. All that said, though, I’m not sure why you’d tell a coworker they look like your ex wife. It was very strange, and needless to say, Karl made a bad impression on Sandra.")
# Out:
# language (DistilBERT Classification Full): Japonic (36.99%) Chinese (18.35%)
# The other day, my middle-aged colleague got in an argument with our new hire, Sandra, because he told her she looked like his ex-wife. When Sandra told me about this conversation, she said, “I’m beginning to think Karl (colleague) isn’t a girls’ girl.” I thought that was pretty funny. All that said, though, I’m not sure why you’d tell a coworker they look like your ex wife. It was very strange, and needless to say, Karl made a bad impression on Sandra.
# language (RoBERTa Classification Full): Nordic (26.42%) English (25.47%)
# ...

# %% [markdown]
# ---
# - age: 40
# - gender: Male
# - political: Prefer not to say
# - mbti: I don’t know / prefer not to share
# - native language branch: Polish

# %%
explain("I'm wondering, is the technological progress helping people happier lives these days? Since the industrial revolution so many breakthroughs have taken place. Are we happier? Do we have more time to spend on the things really important to us? Or is the result the complete opposite? We come under constantly increasing pressure to achieve more, deliver more, etc. Does this make sense?!")
# Out:
# language (DistilBERT Classification Full): Arabic (33.26%) Chinese (22.10%)
# I'm wondering, is the technological progress helping people happier lives these days? Since the industrial revolution so many breakthroughs have taken place. Are we happier? Do we have more time to spend on the things really important to us? Or is the result the complete opposite? We come under constantly increasing pressure to achieve more, deliver more, etc. Does this make sense?!
# language (RoBERTa Classification Full): Spanish (47.49%) Arabic (25.08%)
# I'm wondering, is the technological progress helping people happier lives these days? Since the industrial revolution so many breakthroughs have taken place. Are we happier? Do we have more time to spend on the things really important to us? Or is the result the complete opposite? We come under constantly increasing pressure to achieve more, deliver more, etc. Does this make sense?!
# ...

# %% [markdown]
# ---
# - age: 17
# - gender: Other / Prefer not to say
# - political: Left
# - mbti: ENFP
# - native language branch: Polish

# %%
explain("Recently I have picked up a new interesting hobby. Ive never been a very athletic person despite taking many classes such as martial arts or team sports like basketball throught my childhood which became a less and less relevant part of my life as I got older. Considering that, it was quite unusual for me to get into sports again. Right now you cold say I suck at this new hobby of mine but I dont plan to give up for at least some time.")
# Out:
# language (DistilBERT Classification Full): Koreanic (68.06%)
# Recently I have picked up a new interesting hobby. Ive never been a very athletic person despite taking many classes such as martial arts or team sports like basketball throught my childhood which became a less and less relevant part of my life as I got older. Considering that, it was quite unusual for me to get into sports again. Right now you cold say I suck at this new hobby of mine but I dont plan to give up for at least some time.
# language (RoBERTa Classification Full): English (41.31%) Spanish (17.40%)
# ...

# %% [markdown]
# ---
# - age: 30
# - gender: Male
# - political: Left
# - mbti: ENFP
# - native language branch: English

# %%
explain("nothing worth saying saying isn't enough let me go again the mud tin cans mud sack lantern lantern in mud before then after lantern before mud before the past after lantern let us go again let us have enough tins mud sack lantern shadow i go he returns i enter he leaves the after in the before in the past ")
# Out:
# language (DistilBERT Classification Full): Chinese (37.02%) Arabic (15.23%)
# nothing worth saying saying isn't enough let me go again the mud tin cans mud sack lantern lantern in mud before then after lantern before mud before the past after lantern let us go again let us have enough tins mud sack lantern shadow i go he returns i enter he leaves the after in the before in the past
# language (RoBERTa Classification Full): Arabic (26.51%) Indo-Iranian (23.56%)
# nothing worth saying saying isn't enough let me go again the mud tin cans mud sack lantern lantern in mud before then after lantern before mud before the past after lantern let us go again let us have enough tins mud sack lantern shadow i go he returns i enter he leaves the after in the before in the past
# language (RoBERTa MixedCNN Full): Indo-Iranian (58.34%)
# ...

# %% [markdown]
# ---
# - age: 23
# - gender: Female
# - political: Right
# - mbti: INFP
# - native language branch: German

# %%
explain("I´m not really creative in writing, so I´ll just tell you something about my dog. He  is a really cute black Labrador, who just became five about two weeks ago. Although he is sometimes trampling on our nerves when he has a phase of stubbornnes, overall he is the best dog we could have wished for. Cuddly, not needing to much attention during the workday, eager to learn in exchange for something delicious to eat and of cause loving the water.")
# Out:
# language (DistilBERT Classification Full): German (39.18%) Italian (15.75%)
# I´m not really creative in writing, so I´ll just tell you something about my dog. He  is a really cute black Labrador, who just became five about two weeks ago. Although he is sometimes trampling on our nerves when he has a phase of stubbornnes, overall he is the best dog we could have wished for. Cuddly, not needing to much attention during the workday, eager to learn in exchange for something delicious to eat and of cause loving the water.
# language (RoBERTa Classification Full): German (25.00%) Spanish (13.68%) Nordic (13.55%)
# ...

# %% [markdown]
# ---
# - age: 30
# - gender: Female
# - political: Left
# - mbti: INTJ
# - native language branch: Chinese

# %%
explain("The most interesting thing I met recently is to see the culture differences between [MASK] and [MASK]. I had a nice talk with my German friends and i enjoyed it so much. Actually I don't really understand the thoughts of people about me. i mean, I do know it. But it's different. I guess it's because i am changing and acting differently when i meet different people. If i could change the world, i will make wars never happen. Because it's disaster. Btw, researcher, you didn't show me how many words i already wrote. i guess it's enough. Wish you luck with your research.")
# Out:
# language (DistilBERT Classification Full): Chinese (34.81%) Koreanic (23.92%)
# The most interesting thing I met recently is to see the culture differences between [MASK] and [MASK]. I had a nice talk with my German friends and i enjoyed it so much. Actually I don't really understand the thoughts of people about me. i mean, I do know it. But it's different. I guess it's because i am changing and acting differently when i meet different people. If i could change the world, i will make wars never happen. Because it's disaster. Btw, researcher, you didn't show me how many words i already wrote. i guess it's enough. Wish you luck with your research.
# language (RoBERTa Classification Full): Chinese (22.10%) Indonesian (18.77%) Vietnamese (13.85%)
# ...

# %% [markdown]
# ---
# - age: 23
# - gender: Female
# - political: Right
# - mbti: INTJ;I don’t know / prefer not to share
# - native language branch: English

# %%
explain("A common occurrence in my life that I recently recounted to my friend came to mind when I read the inspiration provided above. As a student researcher, I often collect data from my university, and it is significantly more difficult to get data from males than from females, for a multitude of reasons. So every few months, I go out to 'pick up single guys'. By 'single guys', I mean males who are sitting alone, and by 'picking up', I mean approaching them awkwardly (as I am), and trying to convince them to show interest in my work and help me with it. As weird and awkward as the description of my activity sounds, it is how it feels, no matter how many times I do it.")
# Out:
# language (DistilBERT Classification Full): Koreanic (35.34%) Japonic (20.53%)
# A common occurrence in my life that I recently recounted to my friend came to mind when I read the inspiration provided above. As a student researcher, I often collect data from my university, and it is significantly more difficult to get data from males than from females, for a multitude of reasons. So every few months, I go out to 'pick up single guys'. By 'single guys', I mean males who are sitting alone, and by 'picking up', I mean approaching them awkwardly (as I am), and trying to convince them to show interest in my work and help me with it. As weird and awkward as the description of my activity sounds, it is how it feels, no matter how many times I do it.
# language (RoBERTa Classification Full): English (86.57%)
# ...

# %% [markdown]
# ---
# - age: 40
# - gender: Female
# - political: Prefer not to say
# - mbti: I don’t know / prefer not to share
# - native language branch: Polish

# %%
explain("It's so hard to write something immediately, when someone expect it from you. So, maybe I should write about my hobby. Do you know that you can solve jigsaw puzzles on time? It's called speed puzzling and you can find a lot of competitions not only in Europe but also in [MASK]. Once a year there is organised the Word Jigsaw Championship where people around the world gather together and solve thousands of puzzles. Everyone can join!")
# Out:
# language (DistilBERT Classification Full): Russian (43.42%) Polish (19.62%)
# It's so hard to write something immediately, when someone expect it from you. So, maybe I should write about my hobby. Do you know that you can solve jigsaw puzzles on time? It's called speed puzzling and you can find a lot of competitions not only in Europe but also in [MASK]. Once a year there is organised the Word Jigsaw Championship where people around the world gather together and solve thousands of puzzles. Everyone can join!
# language (RoBERTa Classification Full): Polish (83.28%)
# ...

# %% [markdown]
# ---
# - age: 40
# - gender: Female
# - political: Prefer not to say
# - mbti: INFP
# - native language branch: Uralic

# %%
explain("If I could change one thing in the world, I would make people to respect the nature more. This is quite all-encompassing because it would mean people ate less meat, chose organic, consumed less materia, recycled, not use single-use products, did not mine minerals so much, etc. I think there would be less wars because war destroys environment even after the battles are over. I firmly believe that if people respected nature more, they would live healthier, happier lives. ")
# Out:
# language (DistilBERT Classification Full): Koreanic (72.99%)
# If I could change one thing in the world, I would make people to respect the nature more. This is quite all-encompassing because it would mean people ate less meat, chose organic, consumed less materia, recycled, not use single-use products, did not mine minerals so much, etc. I think there would be less wars because war destroys environment even after the battles are over. I firmly believe that if people respected nature more, they would live healthier, happier lives.
# language (RoBERTa Classification Full): Chinese (43.67%) Japonic (16.59%)
# ...

# %% [markdown]
# ---
# - age: 30
# - gender: Female
# - political: Left
# - mbti: ISFP
# - native language branch: Polish

# %%
explain("If I could change one thing about the world I would make people more free because nowadays people are the slaves of the system in different categories like work, lifestyle, education. People even donit realize how much their freedom is limited.")
# Out:
# language (DistilBERT Classification Full): Spanish (93.48%)
# If I could change one thing about the world I would make people more free because nowadays people are the slaves of the system in different categories like work, lifestyle, education. People even donit realize how much their freedom is limited.
# language (RoBERTa Classification Full): Spanish (41.34%) Arabic (17.22%)
# If I could change one thing about the world I would make people more free because nowadays people are the slaves of the system in different categories like work, lifestyle, education. People even donit realize how much their freedom is limited.
# language (RoBERTa MixedCNN Full): Spanish (27.13%) Arabic (14.19%) Russian (7.81%) Polish (6.96%)
# If I could change one thing about the world I would make people more free because nowadays people are the slaves of the system in different categories like work, lifestyle, education. People even donit realize how much their freedom is limited.
# ...

# %% [markdown]
# ---
# - age: 40
# - gender: Female
# - political: Right
# - mbti: I don’t know / prefer not to share
# - native language branch: Polish

# %%
explain("Once of a night i was a sweet dream about beutifull world. There was peace and love, no one war and drama. Every people of the world was happy and smile ewery day. The landscape have beautifull colours, birds sing has songs and sun was shining. Everything was perfect and magical. Unfortunatelly it was only sweet dream. When i woke up in the ewening is back to normal, gray reality.")
# Out:
# language (DistilBERT Classification Full): Arabic (31.58%) Turkic (20.96%)
# Once of a night i was a sweet dream about beutifull world. There was peace and love, no one war and drama. Every people of the world was happy and smile ewery day. The landscape have beautifull colours, birds sing has songs and sun was shining. Everything was perfect and magical. Unfortunatelly it was only sweet dream. When i woke up in the ewening is back to normal, gray reality.
# language (RoBERTa Classification Full): Polish (62.05%)
# Once of a night i was a sweet dream about beutifull world. There was peace and love, no one war and drama. Every people of the world was happy and smile ewery day. The landscape have beautifull colours, birds sing has songs and sun was shining. Everything was perfect and magical. Unfortunatelly it was only sweet dream. When i woke up in the ewening is back to normal, gray reality.
# language (RoBERTa MixedCNN Full): Russian (63.66%)
# ...

# %% [markdown]
# ---
# - age: 23
# - gender: Female
# - political: Right
# - mbti: I don’t know / prefer not to share
# - native language branch: Polish

# %%
explain("If I could change one thing in the world it would be to make every experience more intense. Every feeling would be strong, and unique, every taste would be either amazing, or straight up awful. All the songs would feel the same as the first time we have heard them, all sights would be just breathtaking, and one of a kind. There would be no getting used to anything, no boring routines. ")
# Out:
# language (DistilBERT Classification Full): Spanish (69.35%)
# If I could change one thing in the world it would be to make every experience more intense. Every feeling would be strong, and unique, every taste would be either amazing, or straight up awful. All the songs would feel the same as the first time we have heard them, all sights would be just breathtaking, and one of a kind. There would be no getting used to anything, no boring routines.
# language (RoBERTa Classification Full): Spanish (70.71%)
# If I could change one thing in the world it would be to make every experience more intense. Every feeling would be strong, and unique, every taste would be either amazing, or straight up awful. All the songs would feel the same as the first time we have heard them, all sights would be just breathtaking, and one of a kind. There would be no getting used to anything, no boring routines.
# language (RoBERTa MixedCNN Full): Spanish (35.59%) Russian (15.74%)
# ...

# %% [markdown]
# ---
# - age: 23
# - gender: Male
# - political: Left
# - mbti: INTP
# - native language branch: English

# %%
explain("There are a lot of things I would change about the world, but probably the most cost-effective would be for people to base their opinions a bit more on data and principles. Of course data we have available is itself biased, but I think many people hold counterproductive or harmful stances that could be remedied by thinking about right and wrong in a more systematic way, rather than based on personal feelings alone. For example, people will default to their own emotions of disgust or religious teachings, which are something unprovable, and base their whole life's project and how they treat people on that.")
# Out:
# language (DistilBERT Classification Full): German (17.54%) Chinese (17.43%) Russian (10.64%) Spanish (8.77%)
# There are a lot of things I would change about the world, but probably the most cost-effective would be for people to base their opinions a bit more on data and principles. Of course data we have available is itself biased, but I think many people hold counterproductive or harmful stances that could be remedied by thinking about right and wrong in a more systematic way, rather than based on personal feelings alone. For example, people will default to their own emotions of disgust or religious teachings, which are something unprovable, and base their whole life's project and how they treat people on that.
# language (RoBERTa Classification Full): German (32.34%) Russian (13.09%) Spanish (10.92%)
# ...

# %% [markdown]
# ---
# - age: 50
# - gender: Female
# - political: Right
# - mbti: ESTP
# - native language branch: Polish

# %%
explain("My first thing is Health. I would like all people are Health on all the word. Physically and mentally. Everyone could be doing everything, what they like. I thing the Wars should be ends. Happines and freedom will give us sens of life.")
# Out:
# language (DistilBERT Classification Full): Turkic (53.47%)
# My first thing is Health. I would like all people are Health on all the word. Physically and mentally. Everyone could be doing everything, what they like. I thing the Wars should be ends. Happines and freedom will give us sens of life.
# language (RoBERTa Classification Full): Polish (77.16%)
# My first thing is Health. I would like all people are Health on all the word. Physically and mentally. Everyone could be doing everything, what they like. I thing the Wars should be ends. Happines and freedom will give us sens of life.
# language (RoBERTa MixedCNN Full): Polish (91.32%)
# My first thing is Health. I would like all people are Health on all the word. Physically and mentally. Everyone could be doing everything, what they like. I thing the Wars should be ends. Happines and freedom will give us sens of life.
# language (RoBERTaLarge MixedCNN Full): Polish (78.75%)
# ...

# %% [markdown]
# ---
# - age: 17
# - gender: Female
# - political: Prefer not to say
# - mbti: ENFJ
# - native language branch: French

# %%
explain("If I could change one thing about the world it would be to make people more understanding and have more empathy. I truly think a lot of problems in the world could be solved with more empathy and understanding. People would be more respectful to each others, they would show more kindness to one another and would help strangers more often too. They would also be more prone to donate to charities and associations that could help solve some of the 17 SDG of the UN. Thank youuu")
# Out:
# language (DistilBERT Classification Full): Spanish (30.09%) French (14.79%) Italian (14.39%)
# If I could change one thing about the world it would be to make people more understanding and have more empathy. I truly think a lot of problems in the world could be solved with more empathy and understanding. People would be more respectful to each others, they would show more kindness to one another and would help strangers more often too. They would also be more prone to donate to charities and associations that could help solve some of the 17 SDG of the UN. Thank youuu
# language (RoBERTa Classification Full): Spanish (24.17%) Indo-Iranian (14.34%) Vietnamese (10.80%) English (10.61%)
# ...

# %% [markdown]
# ---
# - age: 30
# - gender: Other / Prefer not to say
# - political: Left
# - mbti: INFP
# - native language branch: English

# %%
explain("what i would change about the world is the way that people are educated. we should be following a constructivist model of education, using learners' natural envrionments to inform our strategies. but people just want to keep using a banking model")
# Out:
# language (DistilBERT Classification Full): Chinese (21.82%) Koreanic (12.60%) Japonic (11.13%) Spanish (9.73%)
# what i would change about the world is the way that people are educated. we should be following a constructivist model of education, using learners' natural envrionments to inform our strategies. but people just want to keep using a banking model
# language (RoBERTa Classification Full): Spanish (49.09%) Chinese (11.20%)
# what i would change about the world is the way that people are educated. we should be following a constructivist model of education, using learners' natural envrionments to inform our strategies. but people just want to keep using a banking model
# language (RoBERTa MixedCNN Full): Spanish (25.21%) English (12.06%) Vietnamese (8.06%) Chinese (7.29%)
# ...

# %% [markdown]
# ---
# - age: 70
# - gender: Female
# - political: Right
# - mbti: ISTJ
# - native language branch: English

# %%
explain("Because a certain amount of crime on Indian reservations has been allowed to occur unchecked, many families who desire a safer community for their children have moved away from the system. As an increasing number of healthy families leave, an increasing percentage who remain are participating in the crime and abuse.  As a result, more children on the reservation end up in need of foster care.  Unfortunately, much of federal funding is tied to tribal membership numbers and child counts.   According to the 2000, 2010 and 2020 US census’, at least 75% of tribal members do NOT live within Indian Country.  As a result of the migration off the reservation, tribal governments have experienced a drop in federal funds.  Some tribal governments, not wanting any further drop in funds, are reticent to admit they no longer have enough safe homes to place children in, so have placed children in homes known to be dangerous.")
# Out:
# language (DistilBERT Classification Full): Koreanic (39.49%) Spanish (16.55%)
# ...

# %% [markdown]
# ---
# - age: 30
# - gender: Female
# - political: Left
# - mbti: INFP
# - native language branch: English

# %%
explain("Last week I had the funniest experience at the grocery store. I was pushing my cart down the aisle when I accidentally bumped into a display of canned goods. Everything started falling and making this huge noise. People turned to look at me and I felt my face getting red. I quickly tried to pick everything up but kept dropping more cans. A store employee came over to help me and we both started laughing about it. She said it happens all the time but I still felt pretty embarrassed. Now whenever I go to that store I try to avoid that aisle. My friends think it's hilarious and keep teasing me about my clumsy moment.")
# Out:
# language (DistilBERT Classification Full): Arabic (38.27%) Koreanic (14.90%)
# Last week I had the funniest experience at the grocery store. I was pushing my cart down the aisle when I accidentally bumped into a display of canned goods. Everything started falling and making this huge noise. People turned to look at me and I felt my face getting red. I quickly tried to pick everything up but kept dropping more cans. A store employee came over to help me and we both started laughing about it. She said it happens all the time but I still felt pretty embarrassed. Now whenever I go to that store I try to avoid that aisle. My friends think it's hilarious and keep teasing me about my clumsy moment.
# language (RoBERTa Classification Full): Arabic (57.73%)
# ...

# %% [markdown]
# ---
# - age: 40
# - gender: Female
# - political: Left
# - mbti: ENTP
# - native language branch: French

# %%
explain("Sometimes I feel that people misunderstand who I am. It may be for the best or for the worst. In both cases, it is a little annoying to see that people draw conclusions very fast on how to categorize me. The most problematic is that once someone has a specific idea about you, they don't appear to change it easily. So, no matter what you do, you'll almost always be categorized as this or that.")
# Out:
# language (DistilBERT Classification Full): Chinese (24.84%) Japonic (12.66%) English (11.07%) French (8.44%)
# Sometimes I feel that people misunderstand who I am. It may be for the best or for the worst. In both cases, it is a little annoying to see that people draw conclusions very fast on how to categorize me. The most problematic is that once someone has a specific idea about you, they don't appear to change it easily. So, no matter what you do, you'll almost always be categorized as this or that.
# language (RoBERTa Classification Full): Spanish (32.62%) Arabic (19.28%)
# Sometimes I feel that people misunderstand who I am. It may be for the best or for the worst. In both cases, it is a little annoying to see that people draw conclusions very fast on how to categorize me. The most problematic is that once someone has a specific idea about you, they don't appear to change it easily. So, no matter what you do, you'll almost always be categorized as this or that.
# ...
